# %%
pip install jupyterlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 73.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.6 MB/s eta 0:00:00
# ...

# %%
# !pip install torch torchvision torchaudio

# %%
# !pip install easyocr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 17.4 MB/s eta 0:00:00
# ...

# %%
import easyocr
import cv2
from matplotlib import pyplot as pyplot
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-85a7254d-c68b-43f8-9df7-a5bc742b28be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85a7254d-c68b-43f8-9df7-a5bc742b28be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
IMAGE_PATH = 'surf.png.jpeg'

reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# []

# %%
if result:
    top_left = tuple(result[0][0][0])
    bottom_right = tuple(result[0][0][2])
    text = result[0][1]
    font = cv2.FONT_HERSHEY_SIMPLEX

    image = cv2.imread(IMAGE_PATH)
    image = cv2.rectangle(image, top_left, bottom_right, (0,255,0), 5)
    image = cv2.putText(image, text, top_left, font, 0.5, (255,255,255), cv2.LINE_AA)

    pyplot.imshow(image)
    pyplot.show()
else:
    print("No text detected in the image.")
# Out:
# No text detected in the image.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e1922d9f-1fe4-4c6b-a1b3-283cfc27942f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1922d9f-1fe4-4c6b-a1b3-283cfc27942f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
IMAGE_PATH = 'out_of_service.jpeg'

reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(IMAGE_PATH)
result
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [([[np.int32(52), np.int32(15)],
#    [np.int32(163), np.int32(15)],
#    [np.int32(163), np.int32(51)],
#    [np.int32(52), np.int32(51)]],
#   'Warningh ',
#   np.float64(0.3724182765493522)),
#  ([[np.int32(22), np.int32(210)],
#    [np.int32(188), np.int32(210)],
#    [np.int32(188), np.int32(236)],
#    [np.int32(22), np.int32(236)]],
#   'Out of Service',
#   np.float64(0.6575242729597307))]

# %%
if result:
    top_left = tuple(result[0][0][0])
    bottom_right = tuple(result[0][0][2])
    text = result[0][1]
    font = cv2.FONT_HERSHEY_SIMPLEX

    image = cv2.imread(IMAGE_PATH)
    image = cv2.rectangle(image, top_left, bottom_right, (0,255,0), 5)
    image = cv2.putText(image, text, top_left, font, 0.5, (255,255,255), cv2.LINE_AA)

    pyplot.imshow(image)
    pyplot.show()
else:
    print("No text detected in the image.")
